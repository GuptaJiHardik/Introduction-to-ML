# %%
import pandas as pd
import numpy as np

# %%
df_music = pd.read_excel('Music.xlsx')
df_music.head()
# Out:
#    Age  Gender    Genre
# 0   20       1  HIP HOP
# 1   24       1  HIP HOP
# 2   26       1  HIP HOP
# 3   27       1     ROCK
# 4   29       1     ROCK

# %%
y =df_music['Genre']
y.head()
# Out:
# 0    HIP HOP
# 1    HIP HOP
# 2    HIP HOP
# 3       ROCK
# 4       ROCK
# Name: Genre, dtype: object

# %%
x = df_music.drop('Genre',axis=1)
x.head()
# Out:
#    Age  Gender
# 0   20       1
# 1   24       1
# 2   26       1
# 3   27       1
# 4   29       1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
#Choose the Model-DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion = 'entropy')

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
model.predict([[23,1]])
# Out:
# C:\Users\Hardik Gupta\miniconda3\envs\ML\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HIP HOP'], dtype=object)

# %%
#Save the model using joblib
import joblib

# %%
joblib.dump(model, 'my_music_recommender')
# Out:
# ['my_music_recommender']

# %%
pwd
# Out:
# 'C:\\Users\\Hardik Gupta\\Documents\\ML'

# %%
pip install pydotplus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.tree import export_graphviz

# %%
export_graphviz(
    model,
    out_file='our_music_recommender.dot',
    feature_names=['Age', 'Gender'],
    class_names=sorted(y.unique()),
    filled=True,
    label='all',
    rounded=True
)

# %%
import pydotplus

# %%
decision_tree=pydotplus.graph_from_dot_file('our_music_recommender.dot')

# %%
from IPython.display import Image

# %%
Image(decision_tree.create_png())
